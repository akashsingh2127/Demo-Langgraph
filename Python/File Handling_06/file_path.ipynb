# %%
import os
os.mkdir('test_directory')  # Create a new directory named 'test_directory'
# Out:
# ['example.txt', 'file_operation.ipynb', 'file_path.ipynb', 'test_directory']

# %%
## getting the list of files nad directories in the current directory
import os
print(os.listdir('.'))
# Out:
# ['example.txt', 'file_operation.ipynb', 'file_path.ipynb', 'test_directory']

# %%
folder_name="folder"
file_name="file.txt"
full_path=os.path.join(folder_name,file_name)
print(full_path)  # Output: folder/file.txt    but remember it won't create the folder or file, it just creates the path string.
# Out:
# folder\file.txt

# %%
import os
print(os.path.isfile('example.txt'))## true

print(os.path.isdir('test_directory'))## true

print(os.path.exists('test.py'))## same logic of directory and path. so it gives False

print(os.path.isfile('test.py'))## test.py is a file in test_directory folder, but our current file (file_path.ipynb) is in File Handling_06. so it gives False


print(f"to check the is Basics_01: {os.path.isdir('Basics_01')}") ## it gives false because currently we r in File Handling_06 folder and Basics_01 is not in this folder, so it gives false. if we give the full path of Basics_01 then it will give true.
# Out:
# True
# True
# False
# False
# to check the is Basics_01: False
