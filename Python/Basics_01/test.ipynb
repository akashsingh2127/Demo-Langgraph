# %%
5+5
# Out:
# 10

# %%
## Python is case sensitive
name="akash"
Name="kapil"
print(name)
print(Name)
# Out:
# akash
# kapil

# %%
## Identation - define blocks commonly space of 4 or (Tab)
age=32
if age>=30:
    print(age)
## above u can see 4 space gap before print(age) under if
# Out:
# 32

# %%
## u can have multiple statements in one line using (;)
x=5;y=2;z=x+y
print(z)
# Out:
# 7

# %%
l=[type(x),
type(True),
type(2.0),
type("akash"),
type('a'),
type([1,2,3]),
type((1,2,3)),
type({1,2,3}),
type({1:"akash"})]
for i in l:
    print(i)
# Out:
# <class 'int'>
# <class 'bool'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'list'>
# <class 'tuple'>
# <class 'set'>
# <class 'dict'>

# %%
## we have type infernce in python- u can change the value of a variable and the type will also be changed
a=2
print(type(a))## will give integer
a="akash"
print(type(a))## will give string
# Out:
# <class 'int'>
# <class 'str'>
