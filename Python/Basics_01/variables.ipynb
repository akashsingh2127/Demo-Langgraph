# %%
## variables r the containers whihc store values of certain data type
a=2
name="akash"
print("name:",name)
print("roll no:",a)
# Out:
# name: akash
# roll no: 2

# %%
## type conversion AND DYNAMIC TYPING- python allows to chnage the type of the variable during run time.

##Questiion might arise ki in c++ or other languages we have fixed memeory for data types like int -4 ytes, char-1 byte etc... so in python durinig dynamic typing doesn't the memory space changes................
##The answer is- No,because Python checks types at runtime and stores data as flexible heap object    
a=5
print(type(a))
a="akash"
print(type(a))
# Out:
# <class 'int'>
# <class 'str'>

# %%
## different types of type conversion....
a=5
print(float(a))# int to float
b=6.0
print(int(b))#float to int
c='25'
print(int(c))#character to int and similarly character to float
d=25
print(type(str(d)))# int or float to string

## REMEMBER U CANT CHANGE A STRING INTO INT OR FLOAT
# Out:
# 5.0
# 6
# 25
# <class 'str'>
