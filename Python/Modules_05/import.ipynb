# %% [markdown]
# ### importing modules in python
#
# modules and packages help in reusing and organizing the code

# %%
import numpy as np ##numpy is basically used for scientific computing and data analysis in python. It provides support for large multi-dimensional arrays and matrices, along with a collection of mathematical functions to operate on these arrays.
a=np.array([[1, 2, 3], [4, 5, 6]])
print(a)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
from math import pi,sqrt
## from math import * will import all the functuions from math module.
print(sqrt(49))
print(sqrt(48))
print(pi)
# Out:
# 7.0
# 6.928203230275509
# 3.141592653589793

# %%
##calling function from Custome package whihc we create just now iside the MODULES_05 folder.

##inside the packages folder we create __inti.py file, a maths.py file where we createed two custom functions addition and subtraction. Now we will call these functions inside the import.ipynb file.
from packages.maths import addition,subtraction
print(addition(10,5))
print(subtraction(10,5))
# Out:
# 15
# 5
