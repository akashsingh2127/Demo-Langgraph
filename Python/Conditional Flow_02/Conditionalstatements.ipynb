# %%
##if elif and else statement
age=12
if age>=18:
    print("u r allowed to vote")
elif 15<age<18:
    print("not now")
else:
    print("too young to vote")
# Out:
# too young to vote

# %%
##nesetd conditional statement(condition inside condition )
num=int(input("enter a number:"))
if num >=0:
    if num%2==0:
        print("even number")
    else:
        print("odd number")
else:
    print("number is negative")
# Out:
# even number

# %%
## MATCH CASE conditionl statements same as SWITCH CASE
num=int(input("Enter a num"))
a=num%2
match a:
    case 1:
        print("Odd Number")
    case 0:
        print("Even Number")
# Out:
# Odd Number

# %%
## TERNARY Operator( condition in one line)
age=24
status="Adult" if age>=18 else "Minor"
## it is same as String status=(age>=18)?"Adult":"Minor" in C++,JAVA,Javascript
print(status)
# Out:
# Adult
